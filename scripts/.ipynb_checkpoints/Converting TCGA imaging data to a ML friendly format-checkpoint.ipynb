# %%
from tcga_utils import download_utils
from tcga_utils import wsi_utils

import pandas as pd
import requests
import json
import re
# Out:
# Traceback (most recent call last):
#
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 3319, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   File "<ipython-input-1-8d748182f390>", line 1, in <module>
#     from tcga_utils import download_utils
#
#   File "/usr/local/lib/python3.6/dist-packages/tcga_utils/__init__.py", line 32, in <module>
#     from tcga_utils import download_utils
#
#   File "/usr/local/lib/python3.6/dist-packages/tcga_utils/download_utils.py", line 56
#     if not os.path.exists(save_direc):
#                                       ^
# TabError: inconsistent use of tabs and spaces in indentation

# %%
df = tcga_utils.load_manifest_file('/data/manifest/gdc_manifest.2020-01-07.txt')

# %%
print(df['id'][0])
# Out:
# 75291120-80c3-4cb6-b503-e3566a8946f4

# %%
tcga_utils.download_by_uuids(df['id'][0], save_folder = '/data/TCGA')
# Out:
# 'TCGA-AO-A12E-01A-01-BSA.9b55ad59-32de-4238-9958-b54e3a43eb2e.svs'

# %%
import openslide

slide = openslide.OpenSlide('TCGA-AO-A12E-01A-01-BSA.9b55ad59-32de-4238-9958-b54e3a43eb2e.svs')

# %%
tiles = wsi_utils.slide_to_tiles(slide)

# %%
import importlib
importlib.reload(wsi_utils)

filtered_tiles = wsi_utils.filter_tiles(tiles)

# %%
print(filtered_tiles.shape)
# Out:
# (116, 512, 512, 3)

# %%
# print(img.shape)
from matplotlib import pyplot as plt
fig, axes = plt.subplots(1,1, figsize=(15,15))
axes.imshow(filtered_tiles[10,...])

# %%
class TCGADataset(object):
    def __init__(self, uuid, mpp=0.5):
        svs_filename = tcga_utils.download_by_uuids(uuid)
        slide = wsi_utils.open_slide(svs_filename)
        tiles = wsi_utils.slide_to_tiles(slide, new_mpp=mpp)
        filtered_tiles = wsi_utils.filter_tiles(tiles)
        
        self.uuid = uuid
        self.tiles = filtered_tiles
        self.mpp = mpp
        return None
